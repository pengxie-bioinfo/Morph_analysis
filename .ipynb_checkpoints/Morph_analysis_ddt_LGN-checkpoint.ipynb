# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, RandomizedPCA
from sklearn.preprocessing import scale
from sklearn.manifold import Isomap, TSNE
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
from utilities import *
import pickle

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ddt = load_features_as_one(['data/features/17302_LGN.dendrite.features'],
                          drop_attr=["Soma Surface"])

_ = plt.bar(range(len(ddt)), sorted(ddt['Number of Nodes']))

ddt = ddt.drop(ddt[ddt['Number of Nodes']<1000].index, axis=0)
ddt = ddt.drop(["066", "040"], axis=0)

# Cell types
celltypes = pd.DataFrame(ddt['Type'])
celltypes['Type']=pd.Categorical(celltypes['Type'])
u_celltypes = list(set(celltypes['Type']))

my_pal = ['C'+str(i) for i in range(len(u_celltypes))]
lut = dict(zip(sorted(u_celltypes), my_pal))
colors = []
for tp in celltypes['Type'].tolist():
    colors.append(lut[tp])

# %%
ddt
# Out:
# ID  Type  Number of Nodes  Number of Stems  Number of Bifurcatons  \
# 048  LGN             1106                4                     37
# 064  LGN             3975                8                     90
# 119  LGN             3667                5                     86
# 121  LGN             2640                9                     72
# 118  LGN             4664                7                     88
# 049  LGN             3404                6                    100
# 039  LGN             2297                6                     82
# 065  LGN             4709                8                    116
# 117  LGN             8790                2                     93
#
# ID   Number of Branches  Number of Tips  Overall Width  Overall Height  \
# 048                  76              40        447.600        1099.900
# 064                 187              99        437.000        1103.000
# 119                 182              97        704.100         942.000
# 121                 154              83        492.801        1116.000
# 118                 184              97        707.000         708.000
# 049                 190             113        674.000         632.699
# 039                 171              90        645.400         696.000
# 065                 246             132        430.100        1069.000
# 117                 193             101       1050.000        1280.000
#
# ID   Overall Depth  Average Diameter         ...           Total Volume  \
# 048         184.73           1.34709         ...                 8638.7
# 064         155.02           1.87733         ...                41585.8
# 119         156.00           1.94080         ...                44794.6
# 121         176.54           1.91058         ...                36926.9
# 118         177.00           1.91712         ...                37970.5
# 049         161.00           1.87491         ...                29393.0
# 039         190.04           1.87296         ...                31979.4
# 065         137.00           1.90054         ...                43925.3
# 117         237.49           1.99934         ...                84387.9
#
# ID   Max Euclidean Distance  Max Path Distance  Max Branch Order  \
# 048                 596.316            649.969                10
# 064                 558.989           1085.760                19
# 119                 582.421            647.454                10
# 121                 757.660            825.375                10
# 118                 439.500            478.761                 9
# 049                 401.160            484.850                10
# 039                 395.260            770.007                18
# 065                 613.311           1147.740                15
# 117                 800.865           1003.540                15
#
# ID   Average Contraction  Average Fragmentation  \
# 048             0.905214                13.5395
# 064             0.892113                20.1283
# 119             0.893126                19.1429
# 121             0.913297                16.1364
# 118             0.867277                24.3424
# 049             0.903024                14.7421
# 039             0.899091                12.4269
# 065             0.912060                18.1341
# 117             0.899798                44.5389
#
# ID   Average Parent-daughter Ratio  Average Bifurcation Angle Local  \
# 048                       0.951957                          88.4259
# 064                       0.984419                          82.9064
# 119                       0.987982                          74.7430
# 121                       0.964570                          78.7288
# 118                       0.974195                          86.7653
# 049                       0.976503                          60.2204
# 039                       1.014750                          82.1932
# 065                       0.994318                          92.8192
# 117                       0.989741                          81.9771
#
# ID   Average Bifurcation Angle Remote  Hausdorff Dimension
# 048                           64.6784              1.23129
# 064                           70.3367              1.32407
# 119                           68.6541              1.23913
# 121                           61.0510              1.23896
# 118                           73.0307              1.17903
# 049                           57.6648              1.20980
# 039                           71.8547              1.26202
# 065                           77.2169              1.33173
# 117                           68.8306              1.25249
#
# [9 rows x 22 columns]

# %%
df = ddt.iloc[:, 1:]
df = pd.DataFrame(scale(df), columns=df.columns, index=df.index.tolist())


corr_feature = df.corr(method='spearman')
_ = sns.clustermap(corr_feature, linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=False, figsize=(6,6))

# %%
# Create a regular PCA model 
pca = PCA(n_components=df.shape[1])
# Fit and transform the data to the model
reduced_data_pca = pca.fit_transform(df)

use_pcs = 8
tp = np.cumsum(pca.explained_variance_ratio_)*100
plt.plot(range(1, len(tp)+1), tp)
plt.xlabel('# Principle Components')
plt.ylabel('% Variance Explained')
plt.axvline(use_pcs, c='r', lw=1, ls='dashed')


# Fit and transform the data to the model
reduced_data_pca = reduced_data_pca[:,:use_pcs]

fig, ax = plt.subplots(1,3, figsize=(20, 7))

# PCA
ax[0].scatter(reduced_data_pca[:, 0], reduced_data_pca[:, 1], c=colors)

# Isomap
print('Running Isomap...')
isomap = Isomap(n_neighbors=4)
X_iso = isomap.fit_transform(reduced_data_pca)
ax[1].scatter(X_iso[:, 0], X_iso[:, 1], c=colors)

# tSNE
print('Running tSNE...')
tsne = TSNE(n_components=2, perplexity=3)
X_tsne = tsne.fit_transform(reduced_data_pca)
ax[2].scatter(X_tsne[:, 0], X_tsne[:, 1], c=colors)
# Out:
# Running Isomap...
# Running tSNE...

# %%
fig, ax = plt.subplots(1,2,figsize=(16,8))
tsne = TSNE(n_components=2, perplexity=2)
X_tsne = tsne.fit_transform(reduced_data_pca)

X_plot = X_tsne

ax[0].scatter(X_plot[:, 0], X_plot[:, 1], c='w')
for ct in u_celltypes:
    lab = (celltypes['Type']==ct)
    ax[0].scatter(X_plot[lab, 0], X_plot[lab, 1], c=lut[ct], label=ct)
ax[0].legend()
ax[0].set_xlabel('tSNE1')
ax[0].set_ylabel('tSNE2')


ax[1].scatter(X_plot[:, 0], X_plot[:, 1], c='w')
for ct in u_celltypes:
    lab = [i for i in range(len(celltypes)) if (celltypes['Type'][i]==ct)] 
    for i in lab:
        ax[1].text(X_plot[i, 0], X_plot[i, 1], df.index[i], {'color':lut[ct]})
ax[1].set_xlabel('tSNE1')
ax[1].set_ylabel('tSNE2')

fig.savefig("Figure/LGN_17302_tSNE.ddt.pdf")

# %%
Z = linkage(df, 'ward')

thres = 6
fig, ax = plt.subplots(1,1,figsize=(20,8))
d = dendrogram(Z, labels=df.index, leaf_rotation=45, leaf_font_size=10,
               color_threshold=thres, orientation="top",
              )
plt.axhline(y=thres, c='grey', lw=1, linestyle='dashed')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance (Ward)')
fig.savefig("Figure/LGN_17302_dendrogram.ddt.pdf")

# transforme the 'cyl' column in a categorical variable. It will allow to put one color on each level.
my_color=celltypes.loc[d['ivl'], 'Type'].cat.codes
 
# Apply the right color to each label
ax = plt.gca()
xlbls = ax.get_xmajorticklabels()
num=-1
for lbl in xlbls:
    num+=1
    lbl.set_color(my_pal[my_color[num]])
    
clusters = pd.DataFrame({'cluster':fcluster(Z, thres, criterion="distance")}, index=df.index)

# corr_cell = pd.DataFrame(reduced_data_pca, index=df.index).transpose().corr(method='pearson')

dist = squareform(pdist(df))
dist = pd.DataFrame(dist, index=df.index, columns=df.index)

g = sns.clustermap(dist, linewidths=0.01, vmax=thres, linecolor='white', 
                   row_colors=colors, col_colors=colors, 
                   row_linkage=Z, col_linkage=Z,
                   annot=False, figsize=(12,12))
g.savefig("Figure/LGN_17302_heatmap.ddt.pdf")
