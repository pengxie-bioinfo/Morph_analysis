# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, RandomizedPCA
from sklearn.preprocessing import scale
from sklearn.manifold import Isomap, TSNE
from sklearn.cluster import KMeans
import seaborn as sns
import ipynb.fs.defs.Utilities

# %matplotlib inline
# Out:
# Traceback (most recent call last):
#
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-30-e6e663617b2d>", line 9, in <module>
#     import ipynb.fs.defs.Utilities
#
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#
#   File "/anaconda3/lib/python3.6/site-packages/ipynb/fs/defs/__init__.py", line 46, in get_code
#     filter_ast(ast.parse(code_from_ipynb(nb))),
#
#   File "/anaconda3/lib/python3.6/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 14
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax

# %%
def load_features(file_names, drop_attr=[]):
    df_list = []
    for file in file_names:
        df = pd.read_csv(file, index_col=[0], header=[0], delimiter="\t", skiprows=[1])
        df = df.dropna(axis=1, how='any').transpose()
        df = df.iloc[:,6:]
        df = df.drop(drop_attr, axis=1)
        df_list.append(df)
    return(df_list)

def feature_hist(df, ncol=4, len_single_plot = 5):
    n = df.shape[1]
    if((n % ncol)==0):
        nrow = int(n / ncol)
    else:
        nrow = int(n / ncol + 1)
        
    print(nrow, ncol)
    fig, ax = plt.subplots(nrow, ncol, figsize=(len_single_plot*ncol, len_single_plot*nrow))
    ax = ax.reshape(-1,)
    for i in range(n):
        ax[i].hist(df.iloc[:,i], label = df.columns[i])
        ax[i].legend()
    return


def feature_hist_compare(df_list, df_names, ncol=4, len_single_plot = 5):
    n = df_list[0].shape[1]
    featuer_names = df_list[0].columns.tolist()
    assert all([df.shape[1]==n for df in df_list])
    assert len(df_list) == len(df_names)
    if((n % ncol)==0):
        nrow = int(n / ncol)
    else:
        nrow = int(n / ncol + 1)
        
    print(nrow, ncol)
    fig, ax = plt.subplots(nrow, ncol, figsize=(len_single_plot*ncol, len_single_plot*nrow))
    ax = ax.reshape(-1,)
    for i in range(n):
        ax[i].set_title(featuer_names[i])
        for j in range(len(df_list)):
            df = df_list[j]
            ax[i].hist(df.iloc[:,i], histtype='step', normed=True, label=df_names[j])
        ax[i].legend()
    return

# %%
cpu, lgn = load_features(
    file_names = ['data/17302_CPU.dendrite.features', 'data/17302_LGN.dendrite.features'],
    drop_attr = ['Soma Surface', 'Average Diameter'])
print('# Features:\t', cpu.shape[1])
print("# CPU:\t", len(cpu))
print("# LGN:\t", len(lgn))
feature_hist_compare([cpu, lgn], ['CPU', 'LGN'])
# Out:
# # Features:	 20
# # CPU:	 56
# # LGN:	 11
# 5 4

# %%
combined = pd.concat([cpu, lgn], axis=0)
# combined = combined[['Number of Branches', 'Number of Bifurcatons']]
# combined = combined.iloc[:,np.array([1,4,5,17,19])]
combined = pd.DataFrame(scale(combined), columns=cpu.columns, index=cpu.index.tolist()+lgn.index.tolist())
plt.figure(figsize=(14,12))
plt.title('Correlation of neurons',y=1.05,size=15)
sns.heatmap(combined.transpose().corr(method='spearman'), linewidths=0.1, vmax=1.0,
            square=True, linecolor='white', annot=False)

plt.figure(figsize=(14,12))
plt.title('Correlation of features',y=1.05,size=15)
sns.heatmap(combined.corr(method='spearman'), linewidths=0.1, vmax=1.0,
            square=True, linecolor='white', annot=False)

# %%
# Create a regular PCA model 
pca = PCA(n_components=5)
# pca = RandomizedPCA(n_components=2)

# Fit and transform the data to the model
reduced_data_pca = pca.fit_transform(combined)

tp = np.cumsum(pca.explained_variance_ratio_)
plt.plot(range(0, len(tp)), tp)

fig, ax = plt.subplots(1,3, figsize=(20, 7))

# PCA
ax[0].scatter(reduced_data_pca[:, 0], reduced_data_pca[:, 1], c=[1]*cpu.shape[0]+[2]*lgn.shape[0])

# Isomap
print('Running Isomap...')
isomap = Isomap(n_neighbors=10)
X_iso = isomap.fit_transform(reduced_data_pca)
ax[1].scatter(X_iso[:, 0], X_iso[:, 1], c=[1]*cpu.shape[0]+[2]*lgn.shape[0])

# tSNE
print('Running tSNE...')
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(reduced_data_pca)
ax[2].scatter(X_tsne[:, 0], X_tsne[:, 1], c=[1]*cpu.shape[0]+[2]*lgn.shape[0])
# Out:
# Running Isomap...
# Running tSNE...

# %%
plt.text?

# %%
colors = ['r']*cpu.shape[0]+['b']*lgn.shape[0]
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c='w')
for i in range(len(combined)):
    plt.text(X_tsne[i,0], X_tsne[i,1], combined.index[i], {'color':colors[i]})

# %%
lgn
# Out:
# ID   Number of Nodes  Number of Stems  Number of Bifurcatons  \
# 039           1098.0             13.0                   38.0
# 040           2399.0             16.0                   62.0
# 048            139.0              6.0                    1.0
# 064           2981.0             11.0                  129.0
# 065           2327.0              7.0                   89.0
# 066           1519.0             12.0                   41.0
# 117           8831.0              2.0                  132.0
# 118           2747.0              7.0                   72.0
# 119           3379.0              9.0                  124.0
# 120           2342.0             13.0                   88.0
# 121           1672.0             11.0                   66.0
#
# ID   Number of Branches  Number of Tips  Overall Width  Overall Height  \
# 039                90.0            53.0        395.000         576.000
# 040               141.0            80.0        547.641         630.000
# 048                 6.0             6.0        109.689         156.551
# 064               288.0           160.0        366.639        1103.000
# 065               190.0           102.0        418.051        1069.000
# 066                93.0            53.0        510.000         719.000
# 117               270.0           139.0       1050.000        1280.000
# 118               152.0            81.0        610.000         708.000
# 119               262.0           139.0        704.070         942.000
# 120               192.0           106.0        526.000         762.000
# 121               143.0            78.0        464.000        1076.000
#
# ID   Overall Depth  Total Length  Total Surface  Total Volume  \
# 039         190.04      5785.950       30621.40      13533.50
# 040         203.56     10243.500       43225.40      14856.70
# 048         120.34       738.352        3189.58       1232.38
# 064         143.01     10003.900       59284.70      32741.80
# 065         110.00      7626.860       44966.60      21567.40
# 066         152.00      5243.620       30014.70      14098.50
# 117         237.49     26863.700      168695.00      84318.50
# 118         164.27      8197.370       47418.50      22442.30
# 119         155.00     13699.600       83846.60      41231.80
# 120         145.77     10286.800       59630.50      33717.50
# 121         176.54      9639.370       55790.90      26415.20
#
# ID   Max Euclidean Distance  Max Path Distance  Max Branch Order  \
# 039                 347.643            409.832               8.0
# 040                 368.063            479.088              10.0
# 048                 126.574            156.702               1.0
# 064                 558.989            980.744              44.0
# 065                 613.311            661.703              16.0
# 066                 465.141            518.996               7.0
# 117                 800.865           1007.630              18.0
# 118                 439.500            477.594              10.0
# 119                 582.421            646.918              15.0
# 120                 447.146            526.713               8.0
# 121                 757.660            824.749               9.0
#
# ID   Average Contraction  Average Fragmentation  \
# 039             0.896750               11.18890
# 040             0.877431               16.00710
# 048             0.765463               22.00000
# 064             0.917631                9.34722
# 065             0.930972               11.24210
# 066             0.909623               15.32260
# 117             0.918478               31.70370
# 118             0.898599               17.06580
# 119             0.920611               11.89310
# 120             0.917203               11.17710
# 121             0.933752               10.68530
#
# ID   Average Parent-daughter Ratio  Average Bifurcation Angle Local  \
# 039                       0.894394                          84.6940
# 040                       0.877652                          86.8192
# 048                       0.066667                          68.1931
# 064                       0.975334                          89.9362
# 065                       0.963545                          83.7615
# 066                       0.889341                         104.2080
# 117                       0.991926                          77.9234
# 118                       0.963311                          77.9168
# 119                       0.980528                          77.7076
# 120                       0.963715                          78.6863
# 121                       0.940576                          81.3180
#
# ID   Average Bifurcation Angle Remote  Hausdorff Dimension
# 039                           73.3223              1.13946
# 040                           70.6223              1.17582
# 048                           38.7993              1.12765
# 064                           84.6636              1.28857
# 065                           73.4367              1.19870
# 066                           89.9729              1.11982
# 117                           66.3054              1.25278
# 118                           67.9886              1.17369
# 119                           68.2856              1.23734
# 120                           71.2881              1.18424
# 121                           66.3088              1.19425

# %%
cpu.sort_values('Number of Tips', ascending=False)
# cpu.sort_values('Overall Width', ascending=False)
# cpu.sort_values('Average Fragmentation', ascending=False)
# Out:
# ID   Number of Nodes  Number of Stems  Number of Bifurcatons  \
# 020           3954.0              7.0                  140.0
# 012           4017.0              4.0                  132.0
# 108           3336.0              4.0                  116.0
# 013           3382.0              5.0                  105.0
# 087           3294.0              5.0                   96.0
# 017           3200.0              7.0                   85.0
# 055           2648.0              2.0                   86.0
# 097           3070.0              5.0                   86.0
# 084           2296.0              5.0                   74.0
# 110           2032.0              4.0                   76.0
# 006           3030.0              4.0                   75.0
# 010           2409.0              4.0                   81.0
# 050           2183.0              3.0                   79.0
# 056           2085.0              5.0                   75.0
# 005           2644.0              5.0                   77.0
# 043           2091.0              8.0                   73.0
# 103           2458.0              4.0                   71.0
# 093           3302.0              4.0                   69.0
# 083           2782.0              6.0                   67.0
# 008           1845.0              5.0                   69.0
# 086           3412.0              2.0                   64.0
# 002           2616.0              3.0                   62.0
# 082           1863.0              7.0                   56.0
# 011           2731.0              5.0                   61.0
# 032           2076.0              5.0                   60.0
# 027           1868.0              4.0                   60.0
# 009           3354.0              3.0                   60.0
# 007           2085.0              5.0                   56.0
# 081           2528.0              4.0                   58.0
# 088           2122.0              4.0                   60.0
# 096           1505.0              4.0                   50.0
# 004           2326.0              2.0                   57.0
# 089           2406.0              5.0                   56.0
# 003           1942.0              6.0                   49.0
# 101           1448.0              4.0                   54.0
# 062           2158.0              5.0                   49.0
# 001           2653.0              7.0                   49.0
# 075           1924.0              7.0                   47.0
# 016           2078.0              6.0                   47.0
# 085           2082.0              6.0                   47.0
# 123           2616.0              5.0                   48.0
# 107           1945.0              5.0                   45.0
# 111           2181.0              3.0                   44.0
# 044           1537.0              8.0                   41.0
# 106           2141.0              5.0                   40.0
# 010                       0.976145                          65.9784
# 050                       0.966832                          34.8333
# 056                       0.963603                          54.7641
# 005                       0.965862                          72.8773
# 043                       0.956482                          69.2153
# 103                       0.954236                          46.4609
# 093                       0.978042                          55.9937
# 083                       0.957266                          60.9519
# 008                       0.965141                          72.4388
# 086                       1.101540                          41.1391
# 002                       0.987645                          58.4484
# 082                       0.924674                          53.1972
# 011                       0.960400                          75.4188
# 032                       0.957016                          64.4637
# 027                       0.980539                          75.2189
# 009                       1.024390                          60.0882
# 007                       0.990944                          88.5537
# 081                       0.966154                          65.2127
# 088                       0.972108                          59.6337
# 096                       0.940422                          46.4203
# 004                       0.973243                          47.7681
# 089                       0.957328                          71.5226
# 003                       0.856561                          63.6490
# 101                       0.959847                          62.8493
# 062                       0.950990                          64.5997
# 001                       0.970655                          75.9847
# 075                       0.922978                          68.6519
# 016                       1.044900                          59.8547
# 085                       0.940000                          83.8792
# 123                       0.962305                          71.6709
# 107                       0.941071                          66.0614
# 111                       0.965862                          89.1928
# 044                       0.911011                          82.1891
# 106                       1.019740                          75.8606
# 030                       0.942609                          63.4817
# 091                       1.018760                          88.6110
# 046                       0.966250                          68.0372
# 124                       0.909706                          67.1894
# 045                       0.859025                          66.2794
# 057                       1.052880                          65.1575
# 031                       0.927587                          64.5348
# 015                       1.078070                          65.0135
# 109                       0.836857                          83.5296
# 042                       0.889578                          52.2817
# 105                       0.897586                          76.5516
#
# ID   Average Bifurcation Angle Remote  Hausdorff Dimension
# 020                           70.9906              1.32539
# 012                           53.5552              1.14202
# 108                           53.9521              1.14670
# 013                           42.8598              1.09738
# 087                           67.2096              1.08201
# 017                           46.0268              1.07617
# 055                           58.9844              1.19465
# 097                           56.2612              1.09758
# 084                           51.4441              1.10987
# 110                           40.6004              1.08685
# 006                           58.7419              1.08358
# 010                           58.8452              1.11658
# 050                           32.2521              1.08623
# 056                           46.7660              1.07851
# 005                           63.8648              1.10595
# 043                           63.4416              1.16828
# 103                           41.1626              1.20589
# 093                           51.2984              1.08393
# 083                           60.3865              1.11244
# 008                           63.9058              1.11918
# 086                           34.3151              1.07005
# 002                           57.0340              1.11104
# 082                           48.0097              1.17543
# 011                           64.7576              1.08889
# 032                           56.5786              1.12984
# 027                           63.2944              1.14199
# 009                           65.5725              1.07558
# 007                           83.6332              1.05717
# 081                           62.2620              1.17665
# 088                           54.7381              1.15503
# 096                           37.3161              1.12989
# 004                           41.5234              1.16563
# 089                           65.6915              1.05675
# 003                           58.9630              1.17562
# 101                           64.7748              1.12703
# 062                           65.9807              1.12541
# 001                           70.2156              1.09087
# 075                           56.9715              1.14748
# 016                           62.5932              1.15876
# 085                           64.7957              1.17343
# 123                           59.7508              1.09911
# 107                           67.2150              1.12102
# 111                           72.2606              1.13450
# 044                           66.0545              1.14409
# 106                           77.7705              1.10159
# 030                           44.7377              1.05712
# 091                           80.7920              1.09377
# 046                           70.1301              1.10980
# 124                           59.9505              1.13771
# 045                           66.9948              1.16401
# 057                           59.6894              1.13530
# 031                           70.1041              1.13883
# 015                           62.8232              1.06329
# 109                           76.2818              1.09420
# 042                           59.6676              1.12123
# 105                           73.0491              1.09871
